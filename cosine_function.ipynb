# %% [markdown]
# ### This notebook will help you if you want to use cosine similarity only
# #### And also a few note for preference understanding fundamental cosine similarity
# #### by Harisabekti Dicky Subrata

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you look at the cosine function, where value of y axes is 1, then theta in x axes = 0, and in other hand while value of y axes is -1, then theta in x axes = 180, that describe possible for two overlapping vectors cosine will be the highest and lowest for two exactly 'opposite' vectors. So, 1 is the maximum similarity value that means two vector comapared is totally similar, and -1 is means that two vector is totalli not similar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
You can use get_cosine function after you got two vector,
the text can be convert into vector using text_to_vector function.
The code should be, for example :

text1 = 'bla-bla'
text2 = 'blu-blu'

vec1 = text_to_vector(text1)
vec2 = text_to_vector(text2)

cosine_similarity_value = get_cosine(vec1, vec2)
'''
# Out:
# "\nYou can use get_cosine function after you got two vector,\nthe text can be convert into vector using text_to_vector function.\nThe code should be, for example :\n\ntext1 = 'bla-bla'\ntext2 = 'blu-blu'\n\nvec1 = text_to_vector(text1)\nvec2 = text_to_vector(text2)\n\ncosine_similarity_value = get_cosine(vec1, vec2)\n"

# %%
def get_cosine(vec1, vec2):
    import math
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x] ** 2 for x in list(vec1.keys())])
    sum2 = sum([vec2[x] ** 2 for x in list(vec2.keys())])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator

# %%
def text_to_vector(text):
    import re
    WORD = re.compile(r"\w+")
        
    from collections import Counter
    words = WORD.findall(text)
    return Counter(words)

# %% [markdown]
# References :
# 1. https://towardsdatascience.com/cosine-similarity-how-does-it-measure-the-similarity-maths-behind-and-usage-in-python-50ad30aad7db
# 2. https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html
